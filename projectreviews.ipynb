# %% [markdown]
# **Jake's Project:**

# %% [markdown]
# Comparing offensive and defensive efficiences and rankings, going into detail about different teams like Liberty vs Southern Miss (best and worst offense), and then going into different teams such as Georgia (best in the SEC and one of the best in the nation), Iowa, and Kentucky.

# %% [markdown]
# **Nick's Project:**

# %% [markdown]
# Looking at at timeline of different entities and countries from 1960's to present and how they've increased or decreased. Also focused in on comparing the big 3: China, US, Russia. Then diving deeper into commercial entities such as SpaceX and seeing their massive growth in the past 15 years.

# %% [markdown]
# **Chris's Project:**

# %% [markdown]
# Going into the top 10 Yu-Gi-Oh trading cards and comparing their different values. Top was around $800. Then he talked about the different sets you can find those cards in, and how some of the top cards aren't in the best selling sets.

# %% [markdown]
# **Sam's Project:**

# %% [markdown]
# Talked about the MUOS and different technical aspects that have to be regulated and watched in order to make sure it can complete its mission and not destabilize/deorbit. Used an airplane and its different movements to help understand the satellite movements.
